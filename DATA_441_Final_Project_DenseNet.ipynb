# %%
from keras.activations import leaky_relu
from sklearn.model_selection import train_test_split as tts
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.regularizers import l1_l2, l2, l1
# for images, use Conv2D, for regression, use Conv1Dr
from tensorflow.keras.layers import Input, BatchNormalization, Dense, Activation, Conv1D, Dropout, ZeroPadding1D, Concatenate, AveragePooling1D, GlobalAveragePooling1D, LeakyReLU, Flatten

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('drive/MyDrive/Colab Notebooks/data/telecom_churn.csv')

# %%
X = data.loc[:, 'AccountWeeks':].values
#y = to_categorical(data['Churn'].values,2)
y = data['Churn'].values

# %% [markdown]
# # Model
#
# ## H function

# %%
def H(  inputs, num_filters , dropout_rate ):
    x = BatchNormalization( epsilon=eps )( inputs )
    x = Activation('relu')(x)
    x = Conv1D(num_filters, kernel_size=(1), use_bias=False , kernel_initializer='he_normal' )(x)
    x = Dropout(rate=dropout_rate )(x)
    return x

# %% [markdown]
# ## Transition Layer

# %%
def transition(inputs, num_filters , compression_factor , dropout_rate ):
    # compression_factor is the 'θ'
    x = BatchNormalization( epsilon=eps )(inputs)
    x = Activation('relu')(x)
    num_feature_maps = inputs.shape[1] # The value of 'm'

    x = Conv1D( np.floor( compression_factor * num_feature_maps ).astype(int) ,
                               kernel_size=(1), use_bias=False, padding='same' , kernel_initializer='he_normal' , kernel_regularizer=l2( 1e-4 ) )(x)
    x = Dropout(rate=dropout_rate)(x)
    
    # x = AveragePooling2D(pool_size=(2, 2))(x)
    return x

# %% [markdown]
# ## Dense Block

# %%
def dense_block( inputs, num_layers, num_filters, growth_rate , dropout_rate ):
    for i in range(num_layers): # num_layers is the value of 'l'
        conv_outputs = H(inputs, num_filters , dropout_rate )
        inputs = Concatenate()([conv_outputs, inputs])
        num_filters += growth_rate # To increase the number of filters for each layer.
    return inputs, num_filters

# %% [markdown]
# ## Initialize Model Inputs and Outputs

# %%
input_shape = ( 10, 1 ) 
num_blocks = 4
num_layers_per_block = 4
growth_rate = 2
dropout_rate = 0.2
compress_factor = 0.5
eps = 1.1e-5

num_filters = 16

inputs = Input( shape=input_shape )
x = Conv1D( num_filters , kernel_size=( 3 ) , use_bias=False, kernel_initializer='he_normal' , kernel_regularizer=l2( 1e-4 ) )( inputs )

for i in range( num_blocks ):
    x, num_filters = dense_block( x, num_layers_per_block , num_filters, growth_rate , dropout_rate )
    x = transition(x, num_filters , compress_factor , dropout_rate )

x = Flatten()(x)
# x = Dense(16,activation='gelu',use_bias=True,kernel_regularizer=l1_l2(l1=0.001,l2=0.01))(x)
# maybe flatten and add a "thinking" layer like gelu
# x = GlobalAveragePooling2D()( x ) 

# x = Dense(2)(x)
# outputs = Activation('softmax')(x)

x = Dense( 1 )( x ) # sigmoid 1 softmax 2
outputs = Activation( 'sigmoid' )( x )

# %% [markdown]
# ## Compile Model

# %%
model = Model( inputs , outputs )
model.compile( loss='binary_crossentropy' ,optimizer=Adam( learning_rate=0.00001 ) ,metrics=[ 'accuracy' ])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 8, 16)        48          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 8, 16)       64          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 8, 16)        0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 8, 16)        256         ['activation[0][0]']
#
#  dropout (Dropout)              (None, 8, 16)        0           ['conv1d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 32)        0           ['dropout[0][0]',
#                                                                   'conv1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 32)       128         ['concatenate[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 8, 32)        0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 8, 18)        576         ['activation_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 8, 18)        0           ['conv1d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 50)        0           ['dropout_1[0][0]',
#                                                                   'concatenate[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 50)       200         ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 8, 50)        0           ['batch_normalization_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 8, 20)        1000        ['activation_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 8, 20)        0           ['conv1d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 70)        0           ['dropout_2[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 70)       280         ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 8, 70)        0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 8, 22)        1540        ['activation_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 22)        0           ['conv1d_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 92)        0           ['dropout_3[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 92)       368         ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 8, 92)        0           ['batch_normalization_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 8, 4)         368         ['activation_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 4)         0           ['conv1d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 4)        16          ['dropout_4[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 4)         0           ['batch_normalization_5[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 8, 24)        96          ['activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 8, 24)        0           ['conv1d_6[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 28)        0           ['dropout_5[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 28)       112         ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 28)        0           ['batch_normalization_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 8, 26)        728         ['activation_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 8, 26)        0           ['conv1d_7[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 54)        0           ['dropout_6[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 8, 54)       216         ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 8, 54)        0           ['batch_normalization_7[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 8, 28)        1512        ['activation_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 8, 28)        0           ['conv1d_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 8, 82)        0           ['dropout_7[0][0]',
#                                                                   'concatenate_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 82)       328         ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 82)        0           ['batch_normalization_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 8, 30)        2460        ['activation_8[0][0]']
#
#  dropout_8 (Dropout)            (None, 8, 30)        0           ['conv1d_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 8, 112)       0           ['dropout_8[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 112)      448         ['concatenate_7[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 112)       0           ['batch_normalization_9[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 8, 4)         448         ['activation_9[0][0]']
#
#  dropout_9 (Dropout)            (None, 8, 4)         0           ['conv1d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 4)        16          ['dropout_9[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 8, 4)         0           ['batch_normalization_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 8, 32)        128         ['activation_10[0][0]']
#
#  dropout_10 (Dropout)           (None, 8, 32)        0           ['conv1d_11[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 8, 36)        0           ['dropout_10[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 8, 36)       144         ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 8, 36)        0           ['batch_normalization_11[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 8, 34)        1224        ['activation_11[0][0]']
#
#  dropout_11 (Dropout)           (None, 8, 34)        0           ['conv1d_12[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 8, 70)        0           ['dropout_11[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 70)       280         ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 8, 70)        0           ['batch_normalization_12[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 8, 36)        2520        ['activation_12[0][0]']
#
#  dropout_12 (Dropout)           (None, 8, 36)        0           ['conv1d_13[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 8, 106)       0           ['dropout_12[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 106)      424         ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 106)       0           ['batch_normalization_13[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 8, 38)        4028        ['activation_13[0][0]']
#
#  dropout_13 (Dropout)           (None, 8, 38)        0           ['conv1d_14[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 8, 144)       0           ['dropout_13[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 8, 144)      576         ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 8, 144)       0           ['batch_normalization_14[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 8, 4)         576         ['activation_14[0][0]']
#
#  dropout_14 (Dropout)           (None, 8, 4)         0           ['conv1d_15[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 8, 4)        16          ['dropout_14[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 8, 4)         0           ['batch_normalization_15[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 8, 40)        160         ['activation_15[0][0]']
#
#  dropout_15 (Dropout)           (None, 8, 40)        0           ['conv1d_16[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 8, 44)        0           ['dropout_15[0][0]',
#                                                                   'dropout_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 8, 44)       176         ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 8, 44)        0           ['batch_normalization_16[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 8, 42)        1848        ['activation_16[0][0]']
#
#  dropout_16 (Dropout)           (None, 8, 42)        0           ['conv1d_17[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 8, 86)        0           ['dropout_16[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 8, 86)       344         ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 8, 86)        0           ['batch_normalization_17[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 8, 44)        3784        ['activation_17[0][0]']
#
#  dropout_17 (Dropout)           (None, 8, 44)        0           ['conv1d_18[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 8, 130)       0           ['dropout_17[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 130)      520         ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 130)       0           ['batch_normalization_18[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 8, 46)        5980        ['activation_18[0][0]']
#
#  dropout_18 (Dropout)           (None, 8, 46)        0           ['conv1d_19[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 8, 176)       0           ['dropout_18[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 176)      704         ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 176)       0           ['batch_normalization_19[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 8, 4)         704         ['activation_19[0][0]']
#
#  dropout_19 (Dropout)           (None, 8, 4)         0           ['conv1d_20[0][0]']
#
#  flatten (Flatten)              (None, 32)           0           ['dropout_19[0][0]']
#
#  dense (Dense)                  (None, 1)            33          ['flatten[0][0]']
#
#  activation_20 (Activation)     (None, 1)            0           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 35,377
# Trainable params: 32,697
# Non-trainable params: 2,680
# __________________________________________________________________________________________________

# %% [markdown]
# ## Application

# %%
batch_size = 16
epochs = 25

x_train, x_test, y_train, y_test = tts(X, y, test_size = 0.25, stratify=y)

model.fit( x_train, y_train, epochs=epochs , batch_size=batch_size , validation_data=( x_test , y_test ) )
# Out:
# Epoch 1/25
# 157/157 [==============================] - 21s 32ms/step - loss: 1.2111 - accuracy: 0.3189 - val_loss: 0.7675 - val_accuracy: 0.1595
# Epoch 2/25
# 157/157 [==============================] - 5s 32ms/step - loss: 1.1082 - accuracy: 0.3593 - val_loss: 0.7538 - val_accuracy: 0.2278
# Epoch 3/25
# 157/157 [==============================] - 6s 37ms/step - loss: 1.0301 - accuracy: 0.3870 - val_loss: 0.7292 - val_accuracy: 0.3285
# Epoch 4/25
# 157/157 [==============================] - 4s 28ms/step - loss: 0.9307 - accuracy: 0.4398 - val_loss: 0.6978 - val_accuracy: 0.4988
# Epoch 5/25
# 157/157 [==============================] - 6s 36ms/step - loss: 0.8749 - accuracy: 0.4630 - val_loss: 0.6629 - val_accuracy: 0.7422
# Epoch 6/25
# 157/157 [==============================] - 5s 33ms/step - loss: 0.8051 - accuracy: 0.5118 - val_loss: 0.6490 - val_accuracy: 0.7878
# Epoch 7/25
# 157/157 [==============================] - 4s 28ms/step - loss: 0.7417 - accuracy: 0.5726 - val_loss: 0.6224 - val_accuracy: 0.8357
# Epoch 8/25
# 157/157 [==============================] - 6s 36ms/step - loss: 0.7159 - accuracy: 0.6094 - val_loss: 0.5975 - val_accuracy: 0.8465
# Epoch 9/25
# 157/157 [==============================] - 4s 29ms/step - loss: 0.6790 - accuracy: 0.6415 - val_loss: 0.5815 - val_accuracy: 0.8549
# Epoch 10/25
# 157/157 [==============================] - 5s 33ms/step - loss: 0.6461 - accuracy: 0.6463 - val_loss: 0.5787 - val_accuracy: 0.8537
# Epoch 11/25
# 157/157 [==============================] - 5s 33ms/step - loss: 0.6293 - accuracy: 0.6911 - val_loss: 0.5621 - val_accuracy: 0.8549
# Epoch 12/25
# 157/157 [==============================] - 5s 29ms/step - loss: 0.5999 - accuracy: 0.7135 - val_loss: 0.5513 - val_accuracy: 0.8549
# Epoch 13/25
# 157/157 [==============================] - 6s 36ms/step - loss: 0.5903 - accuracy: 0.7291 - val_loss: 0.5226 - val_accuracy: 0.8549
# Epoch 14/25
# 157/157 [==============================] - 4s 28ms/step - loss: 0.5754 - accuracy: 0.7447 - val_loss: 0.5245 - val_accuracy: 0.8549
# Epoch 15/25
# 157/157 [==============================] - 4s 28ms/step - loss: 0.5689 - accuracy: 0.7587 - val_loss: 0.5087 - val_accuracy: 0.8549
# Epoch 16/25
# 157/157 [==============================] - 5s 35ms/step - loss: 0.5529 - accuracy: 0.7759 - val_loss: 0.4969 - val_accuracy: 0.8549
# Epoch 17/25
# 157/157 [==============================] - 4s 28ms/step - loss: 0.5396 - accuracy: 0.7759 - val_loss: 0.4887 - val_accuracy: 0.8549
# Epoch 18/25
# 157/157 [==============================] - 5s 29ms/step - loss: 0.5247 - accuracy: 0.7891 - val_loss: 0.4761 - val_accuracy: 0.8549
# Epoch 19/25
# 157/157 [==============================] - 6s 36ms/step - loss: 0.5215 - accuracy: 0.8007 - val_loss: 0.4641 - val_accuracy: 0.8549
# Epoch 20/25
# 157/157 [==============================] - 5s 29ms/step - loss: 0.5178 - accuracy: 0.8031 - val_loss: 0.4646 - val_accuracy: 0.8549
# Epoch 21/25
# 157/157 [==============================] - 5s 32ms/step - loss: 0.5085 - accuracy: 0.8115 - val_loss: 0.4568 - val_accuracy: 0.8549
# Epoch 22/25
# 157/157 [==============================] - 5s 34ms/step - loss: 0.5303 - accuracy: 0.8159 - val_loss: 0.4551 - val_accuracy: 0.8549
# Epoch 23/25
# 157/157 [==============================] - 5s 29ms/step - loss: 0.5180 - accuracy: 0.8167 - val_loss: 0.4514 - val_accuracy: 0.8549
# Epoch 24/25
# 157/157 [==============================] - 6s 37ms/step - loss: 0.4995 - accuracy: 0.8219 - val_loss: 0.4418 - val_accuracy: 0.8549
# Epoch 25/25
# 157/157 [==============================] - 5s 29ms/step - loss: 0.5038 - accuracy: 0.8247 - val_loss: 0.4412 - val_accuracy: 0.8549

# %% [markdown]
# Softmax Results

# %%
results = model.evaluate(x_test, y_test, batch_size=batch_size)
print( 'Loss = {} and Accuracy = {} %'.format( results[0] , results[1] * 100 ) )
# Out:
# 53/53 [==============================] - 0s 5ms/step - loss: 0.4662 - accuracy: 0.8549
# Loss = 0.46621909737586975 and Accuracy = 85.49160957336426 %

# %% [markdown]
# Sigmoid Results

# %%
results = model.evaluate(x_test, y_test, batch_size=batch_size)
print( 'Loss = {} and Accuracy = {} %'.format( results[0] , results[1] * 100 ) )
# Out:
# 53/53 [==============================] - 1s 10ms/step - loss: 0.4412 - accuracy: 0.8549
# Loss = 0.44123995304107666 and Accuracy = 85.49160957336426 %
